# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
loan = pd.read_csv('Loan.csv')

# %%
axes=plt.subplots(1,2,sharey=True,figsize=(10,4))

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Create 2 subplots for demonstration
sns.boxplot(x='Loan_Status',data=loan,ax=axes[0])
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
print(loan.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
sns.violinplot(x='Loan_Status',y='Education',data=loan,ax=axes[1])
# Out:
# <Axes: xlabel='Loan_Status', ylabel='Education'>
